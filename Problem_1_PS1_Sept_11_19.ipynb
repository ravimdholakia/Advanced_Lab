# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.stats import norm

Gaussian = np.random.normal(0,3,100)
x = np.linspace(-10,10,100)

x=np.arange(-10,10,.5)

plt.title("1-D Gaussian Range")
plt.plot(Gaussian,np.ones(N),'r.')
plt.xlabel("Value(N/A)")
plt.ylabel("Value(N/A)")
#plt.xlim(-10,10)
#plt.ylim(-1,2)
plt.show()

plt.title("Normalized Gaussian")
plt.plot(x,norm.pdf(x,0,3),'b.')
plt.xlabel("Value(N/A)")
plt.ylabel("Value(N/A)")
plt.show()
